# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv('movies.csv')
bank = pd.read_csv('banknotes.csv')
petrol = pd.read_csv('petrol_consumption.csv')

# %%
movies.head()
# Out:
#                      Movie     Budget  Celebrities             Class
# 0            The 400 Blows  100000000          2.0  Box Office Burst
# 1                La Haine   210000000          3.0  Box Office Burst
# 2            The Godfather  250000000          4.0  Box Office Burst
# 3  The Godfather: Part II   350000000          2.0  Box Office Burst
# 4           Man Bites Dog   400600000          4.0  Box Office Burst

# %%
movies.dtypes
# Out:
# Movie           object
# Budget           int64
# Celebrities    float64
# Class           object
# dtype: object

# %%
sns.jointplot(x='Budget', y='Celebrities',  data=movies, hue='Class')

# %%
x = movies[['Celebrities','Budget']]
y = movies['Class']

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state=0)

# %%
dt.fit(x,y)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
new = [[4, 9250000000], [8, 625000000]]

# %%
dt.predict(new)
# Out:
# C:\Users\duasp\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Mainstream Hit', 'Critical Success'], dtype=object)
